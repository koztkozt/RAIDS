# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib as mpl

# %%
import numpy as np
import matplotlib.pyplot as plt

# ~~~~~~~~~~~~~~~~Overall_Accuracy~~~~~~~~~~~~~~~~
# Abrupt
labels = ["Udacity", "Udacity_sim", "Apollo", "Chen_2017", "Chen_2018", "Comma.ai"]
IDS = [0.7586877483723683, 0, 0, 0.6688445162237557, 0.7945999582201797, 0]
RAIDS = [0.9655872156929061, 0, 0, 0.9610189399500807, 0.986421558387299, 0]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, IDS, (width - 0.05), label="IDS_wo_rc", color="k")
rects2 = ax.bar(x + width / 2, RAIDS, (width - 0.05), label="RAIDS", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Accuracy (100%)")
ax.set_title("Abrupt Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=len(labels))

fig.tight_layout()

plt.show()

# Directed
labels = ["Udacity", "Udacity_sim", "Apollo", "Chen_2017", "Chen_2018", "Comma.ai"]
IDS = [0.7875200811702038, 0, 0, 0.9356188518572897, 0.9441717150616252, 0]
RAIDS = [0.9926439502832501, 0, 0, 0.9748935545441199, 0.9835491957384583, 0]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, IDS, (width - 0.05), label="IDS_wo_rc", color="k")
rects2 = ax.bar(x + width / 2, RAIDS, (width - 0.05), label="RAIDS", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Accuracy (100%)")
ax.set_title("Directed Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed") 
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=len(labels))

fig.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ~~~~~~~~~~~~~~~~Overall_Accuracy~~~~~~~~~~~~~~~~
# Abrupt
labels = ["Udacity", "Chen_2017", "Chen_2018"]
IDS = [0.7586877483723683, 0.6688445162237557, 0.7945999582201797]
RAIDS = [0.9655872156929061, 0.9610189399500807, 0.986421558387299]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, IDS, (width - 0.05), label="IDS_wo_rc", color="k")
rects2 = ax.bar(x + width / 2, RAIDS, (width - 0.05), label="RAIDS", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Accuracy (100%)")
# ax.set_title("Abrupt Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.1), ncol=len(labels))
ax.set_ylim([0, 1])
fig.tight_layout()

plt.show()
fig.savefig("report_image/raids_abrupt.pdf")
# Directed
labels = ["Udacity", "Chen_2017", "Chen_2018"]
IDS = [0.7875200811702038, 0.9356188518572897, 0.9441717150616252]
RAIDS = [0.9926439502832501, 0.9748935545441199, 0.9835491957384583]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, IDS, (width - 0.05), label="IDS_wo_rc", color="k")
rects2 = ax.bar(x + width / 2, RAIDS, (width - 0.05), label="RAIDS", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Accuracy (100%)")
# ax.set_title("Directed Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.1), ncol=len(labels))
ax.set_ylim([0, 1])
fig.tight_layout()

plt.show()
fig.savefig("report_image/raids_directed.pdf")

# %%
# ~~~~~~~~~~~~~~~~Chen_2018~~~~~~~~~~~~~~~~
# Abrupt
# TP, FN,TN,FP
labels = ["Detected \nIntrusions", "Unreported \nIntrusions", "Normal \nCases", "False \nAlarms"]
IDS = [0.393144, 0.606856, 0.965525, 0.034475]
RAIDS = [0.993704092, 0.006295908, 0.983320923, 0.016679077]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, IDS, (width - 0.05), label="IDS_wo_rc", color="k")
rects2 = ax.bar(x + width / 2, RAIDS, (width - 0.05), label="RAIDS", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Accuracy (100%)")
# ax.set_title("Chen_2018 - Abrupt Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=len(labels))
ax.set_ylim([0, 1])
fig.tight_layout()
fig.set_size_inches(4, 3)
plt.show()
fig.savefig("report_image/raids_abrupt_Chen_2018.pdf")
# Directed
labels = ["Detected \nIntrusions", "Unreported \nIntrusions", "Normal \nCases", "False \nAlarms"]
IDS = [0.63087016574585630,0.36912983425414364,1.0,0.0]
RAIDS = [0.9247237569060773, 0.07527624309392265, 0.9940315038149151, 0.005968496185084913]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, IDS, (width - 0.05), label="IDS_wo_rc", color="k")
rects2 = ax.bar(x + width / 2, RAIDS, (width - 0.05), label="RAIDS", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Accuracy (100%)")
# ax.set_title("Chen_2018 - Directed Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=len(labels))
ax.set_ylim([0, 1])
fig.tight_layout()
fig.set_size_inches(4, 3)
plt.show()
fig.savefig("report_image/raids_directed_Chen_2018.pdf")

# %%
# ~~~~~~~~~~~~~~~~Chen_2017~~~~~~~~~~~~~~~~
# Abrupt
labels = ["Detected \nIntrusions", "Unreported \nIntrusions", "Normal \nCases", "False \nAlarms"]
IDS = [0.43226120857699807, 0.567738791423002, 0.770855221685228, 0.229144778314772]
RAIDS = [0.9602826510721247, 0.03971734892787524, 0.9613364152132801, 0.0386635847867199]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, IDS, (width - 0.05), label="IDS_wo_rc", color="k")
rects2 = ax.bar(x + width / 2, RAIDS, (width - 0.05), label="RAIDS", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Accuracy (100%)")
# ax.set_title("Chen_2017 - Abrupt Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=len(labels))
ax.set_ylim([0, 1])
fig.tight_layout()
fig.set_size_inches(4, 3)
plt.show()
fig.savefig("report_image/raids_abrupt_Chen_2017.pdf")
# Directed
labels = ["Detected \nIntrusions", "Unreported \nIntrusions", "Normal \nCases", "False \nAlarms"]
IDS = [0.8091818973020017, 0.19081810269799826, 1.0, 0.0]
RAIDS = [0.9558311575282855, 0.044168842471714535, 0.9846000443164192, 0.015399955683580767]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, IDS, (width - 0.05), label="IDS_wo_rc", color="k")
rects2 = ax.bar(x + width / 2, RAIDS, (width - 0.05), label="RAIDS", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Accuracy (100%)")
# ax.set_title("Chen_2017 - Directed Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=len(labels))
ax.set_ylim([0, 1])
fig.tight_layout()
fig.set_size_inches(4, 3)
plt.show()
fig.savefig("report_image/raids_directed_Chen_2017.pdf")

# %%
# ~~~~~~~~~~~~~~~~Udacity~~~~~~~~~~~~~~~~
# Abrupt
labels = ["Detected \nIntrusions", "Unreported \nIntrusions", "Normal \nCases", "False \nAlarms"]
IDS = [0.43532763532763535, 0.5646723646723647, 0.8951545028255381, 0.10484549717446194]
RAIDS = [0.9891737891737892, 0.010826210826210826, 0.9556330407598894, 0.044366959240110616]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, IDS, (width - 0.05), label="IDS_wo_rc", color="k")
rects2 = ax.bar(x + width / 2, RAIDS, (width - 0.05), label="RAIDS", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Accuracy (100%)")
# ax.set_title("Udacity - Abrupt Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=len(labels))
ax.set_ylim([0, 1])
fig.tight_layout()
fig.set_size_inches(4, 3)
plt.show()
fig.savefig("report_image/raids_abrupt_Udacity.pdf")
# Directed
labels = ["Detected \nIntrusions", "Unreported \nIntrusions", "Normal \nCases", "False \nAlarms"]
IDS = [0.1657754010695187, 0.8342245989304813, 0.9980758347481608, 0.0019241652518392756]
RAIDS = [0.9866310160427807, 0.013368983957219251, 0.9946802490096208, 0.0053197509903791735]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, IDS, (width - 0.05), label="IDS_wo_rc", color="k")
rects2 = ax.bar(x + width / 2, RAIDS, (width - 0.05), label="RAIDS", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Accuracy (100%)")
# ax.set_title("Udacity - Directed Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=len(labels))
ax.set_ylim([0, 1])
fig.tight_layout()
fig.set_size_inches(4, 3)
plt.show()
fig.savefig("report_image/raids_directed_Udacity.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt

# ~~~~~~~~~~~~~~~~Response Time~~~~~~~~~~~~~~~~
# Abrupt
labels = ["Udacity", "Chen_2017", "Chen_2018"]
Average = [0.079402, 0.083139, 0.081850]
Maximum = [0.470151, 0.464294, 0.499800]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, Average, (width - 0.05), label="Average", color="k")
rects2 = ax.bar(x + width / 2, Maximum, (width - 0.05), label="Maximum", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Time (second)")
ax.set_title("Abrupt Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=len(labels))
ax.set_ylim([0, 1])
fig.tight_layout()

plt.show()

# Directed
labels = ["Udacity", "Chen_2017", "Chen_2018"]
Average = [0.082010, 0.085357, 0.082648]
Maximum = [0.533646, 0.486105, 0.512944]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width / 2, Average, (width - 0.05), label="Average", color="k")
rects2 = ax.bar(x + width / 2, Maximum, (width - 0.05), label="Maximum", color="white", hatch="..", edgecolor="black")

ax.set_ylabel("Time (second)")
ax.set_title("Directed Intrusion (2022)")
ax.set_xticks(x, labels)
ax.set_axisbelow(True)
ax.yaxis.grid(color="gray", linestyle="dashed")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=len(labels))
ax.set_ylim([0, 1])
fig.tight_layout()

plt.show()
